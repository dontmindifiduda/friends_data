# %%
import pandas as pd
import numpy as np
import re
import string
import os
import csv

def clean_line(line):
    if line == '' or line == None:
        return 'delete'
    elif line[0] == '[':
        return 'scene'
    elif line[0] == '(' and line[-1] == ')': 
        return 'direction'
    elif ':' in line:
        return 'character'
    elif line == "Opening Credits":
        return 'credits'
    elif line == 'Commercial Break':
        return 'commercials'
    elif line == 'End':
        return 'end'
    else:
        return 'dialogue'

def remove_returns(line):
    if line != None:
        return line.replace('\n', '')

def read_file(file_path):
    df = pd.read_csv(file_path, header=None, encoding="utf-8")
    df.columns = ['lines']
    for i in range(len(df['lines'])):
        if np.isnan(df['lines'][i]):
            df['lines'][i] = ''
            
    print(file_path)
    # Get episode title
    
    title = file_path.replace('friendsscraper/spiders/ep-', '')
    
    print(title)
    
    # Remove rows that will not be included in analysis
    print(df.lines.str.contains('[', regex=False))
    script = df[df.lines.str.contains('[', regex=False).idxmax():]
    
    script = script.applymap(remove_returns)
    
    script['clean_code'] = list(map(clean_line, script['lines']))
    script.set_index('clean_code', inplace=True)
    
    if 'delete' in script.index:
        script.drop('delete', axis=0, inplace=True)
    
    lines = script['lines'].values
    
    return (lines, title) #, writers)

def clean_scenes(scene):
    if scene not in [None, 'Opening Credits', 'End', 'Commercial Break']:
        return scene.replace('[Scene:', '').replace(']', '').replace(')', '').replace('\xa0', '').strip()
    else:
        return scene
    
def dir_from_scene(scene):
    if scene not in [None, 'Opening Credits', 'End', 'Commercial Break']:
        search = {',', '.'}
        delim_index = next((i for i, ch in enumerate(scene) if ch in search), None)
        if delim_index == None:
            delim = ','
        else:
            delim = scene[delim_index]
        if scene.split(delim)[1:] != '':
            #print(scene.split(delim))
            #print(' '.join(scene.split(delim)[1:]))
            return ' '.join(scene.split(delim)[1:])
        else: 
            return None
    else: 
        return None

def isolate_scene(scene):
    if scene not in [None, 'Opening Credits', 'End', 'Commercial Break']:
        search = {',', '.'}
        delim_index = next((i for i, ch in enumerate(scene) if ch in search), None)
        if delim_index == None:
            delim = ','
        else:
            delim = scene[delim_index]
        return scene.split(delim)[0]
    else:
        return scene
    
def clean_directions(direction):
    if direction != None:
        return direction.replace('(', '').replace(')', '')
    else:
        return direction
    
def text_clean(line):
    if line != None and type(line) != list:
        return line.lower().strip().translate(str.maketrans('', '', string.punctuation))
    else: 
        return line

def process_script(lines, title): #, writers):

    dialogue = []
    character = []
    scene = []
    episode = []
    direction = []
    # written_by = []
    
    def update_lists(dia, char, scn, ep, direct): #, wrt):
        dialogue.append(dia)
        character.append(char)
        scene.append(scn)
        episode.append(ep.rstrip('csv'))
        direction.append(direct)
        #written_by.append(wrt)

    current_scene = None
    current_dialogue = None
    current_character = None
    colon_in_front = False

    i = 0 

    while i < len(lines):
        if 'Scene:' in lines[i]:
            current_scene = lines[i]
            current_dialogue = None
            current_character = None

        elif (lines[i][0] == '(' and lines[i][-1] == ')') or ('Scene:' not in lines[i] and (lines[i][0] == '[' and lines[i][-1] == ']')):
            current_character = None
            current_dialogue = None
            update_lists(current_dialogue, current_character, current_scene, title, lines[i])# , writers)


        elif ':' in lines[i]:
            if lines[i][0] == ':':
                current_character = lines[i-1].strip()
                current_dialogue = lines[i].strip(':')
                colon_in_front = True
            elif lines[i].split(':')[1] != '':
                current_character = lines[i].split(':')[0]
                current_dialogue = lines[i].split(':')[1]
            else:
                current_character = lines[i].strip(':')
                current_dialogue = None
                
            if lines[i-1].strip()[-3:] == 'and':
                current_character = lines[i-1] + ' ' + current_character
            
        elif (lines[i] == 'Opening Credits' or lines[i] == 'Commercial Break') or lines[i] == 'End':
            current_character = None
            current_dialogue = None  
            update_lists(current_dialogue, current_character, lines[i], title, None) #, writers)
       
        else:
            if current_dialogue == None:
                current_dialogue = lines[i]
            else:
                current_dialogue += ' ' + lines[i]
        
        if i + 1 < len(lines) and current_dialogue != None and (lines[i+1][0] == '[' or (lines[i+1][0] == '(' and lines[i+1][-1] == ')') or ':' in lines[i+1] or lines[i+1] == 'Opening Credits' or lines[i+1] == 'Commercial Break' or lines[i+1] == 'End'):
            
            if colon_in_front:
                current_dialogue = current_dialogue.lower().strip()
                if (current_dialogue.endswith('monica') or current_dialogue.endswith('doctor')) or (current_dialogue.endswith('rachel') or current_dialogue.endswith('phoebe')):
                    current_dialogue = current_dialogue[:-6]
                elif current_dialogue.endswith('ross') or current_dialogue.endswith('joey'):
                    current_dialogue = current_dialogue[:-4]
                elif current_dialogue.endswith('chandler'):
                    current_dialogue = current_dialogue[:-8]
                elif current_dialogue.endswith('erica'):
                    current_dialogue = current_dialogue[:-5]
                elif current_dialogue.endswith('gate attendant #1') or current_dialogue.endswith('gate attendant #2'):
                    current_dialogue = current_dialogue[:-17]
                elif (current_dialogue.endswith('ticket agent') or current_dialogue.endswith('passenger #1')) or (current_dialogue.endswith('passenger #2') or current_dialogue.endswith('passenger #3')):
                    current_dialogue = current_dialogue[:-12]
                elif current_dialogue.endswith('air stewerdess'):
                    current_dialogue = current_dialogue[:-14]
                
                if current_dialogue != '':
                    update_lists(current_dialogue, current_character, current_scene, title, None) #, writers)
            else:
                update_lists(current_dialogue, current_character, current_scene, title, None) #, writers)


        i += 1
    
    script_df = pd.DataFrame(list(zip(episode, scene, direction, character, dialogue)), columns=['episode', 'scene', 'direction', 'characters', 'dialogue'])
    
    script_df['scene']  = list(map(clean_scenes, script_df['scene']))
    
    for i in range(len(script_df)):
        if i == 0 or script_df['scene'][i] != script_df['scene'][i-1]:
            if script_df['direction'][0] == '' or script_df['direction'][0] == None:
                script_df['direction'][i] = dir_from_scene(script_df['scene'][i])
            elif script_df['direction'][i] != None and dir_from_scene(script_df['scene'][i]) != None:
                script_df['direction'][i] = script_df['direction'][i] + ' ' + dir_from_scene(script_df['scene'][i])
            #print(dir_from_scene(script_df['scene'][i]))
            
    for i in range(len(script_df)):
        
        if script_df['dialogue'][i] != None and '(' in script_df['dialogue'][i]:
            script_df['direction'][i] = script_df['dialogue'][i][script_df['dialogue'][i].find("(") + 1:script_df['dialogue'][i].find(")")]
            script_df['dialogue'][i] = re.sub("[\(].*?[\)]", '', script_df['dialogue'][i])

        
    script_df['scene'] = list(map(isolate_scene, script_df['scene']))
    script_df['direction'] = list(map(clean_directions, script_df['direction']))
    
    return script_df.applymap(text_clean)

# %%
for episode in os.listdir('friendsscraper/spiders/'):
    if 'ep-' in episode: 
        path = 'friendsscraper/spiders/' + episode
        raw_lines, ep_title = read_file(path)
        df = process_script(raw_lines, ep_title)
        ep_title = ep_title.lower()
        df.to_csv('friendsscraper/spiders/processed_ep_%s' % ep_title, index=False)
# Out:
# friendsscraper/spiders/ep-the one with ross tan.csv
# the one with ross tan.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 582    False
# 583    False
# 584    False
# 585    False
# 586    False
# 587    False
# 588    False
# 589    False
# 590     True
# 591    False
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 600    False
# 601    False
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# 607    False
# 608    False
# 609    False
# 610    False
# 611    False
# Name: lines, Length: 612, dtype: bool
# friendsscraper/spiders/ep-the one with the screamer.csv
# the one with the screamer.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 589    False
# 590    False
# 591    False
# 592    False
# 593     True
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 600    False
# 601    False
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# 607    False
# 608    False
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616    False
# 617    False
# 618    False
# Name: lines, Length: 619, dtype: bool
# friendsscraper/spiders/ep-the one with the sonogram at the end.csv
# the one with the sonogram at the end.csv
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# 506    False
# 507    False
# 508    False
# 509    False
# 510    False
# 511    False
# 512    False
# 513    False
# 514    False
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521    False
# 522    False
# Name: lines, Length: 523, dtype: bool
# friendsscraper/spiders/ep-the one with phoebes wedding.csv
# the one with phoebes wedding.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 704    False
# 705    False
# 706    False
# 707    False
# 708    False
# 709    False
# 710    False
# 711    False
# 712    False
# 713    False
# 714    False
# 715    False
# 716    False
# 717     True
# 718    False
# 719    False
# 720    False
# 721    False
# 722    False
# 723    False
# 724    False
# 725    False
# 726    False
# 727    False
# 728    False
# 729    False
# 730    False
# 731    False
# 732    False
# 733    False
# Name: lines, Length: 734, dtype: bool
# friendsscraper/spiders/ep-the one with the fake monica.csv
# the one with the fake monica.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 458    False
# 459    False
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# 465    False
# 466    False
# 467    False
# 468    False
# 469    False
# 470    False
# 471    False
# 472    False
# 473    False
# 474     True
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# 480    False
# 481    False
# 482    False
# 483    False
# 484    False
# 485    False
# 486    False
# 487    False
# Name: lines, Length: 488, dtype: bool
# friendsscraper/spiders/ep-the one with joeys fridge.csv
# the one with joeys fridge.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 667     True
# 668    False
# 669    False
# 670    False
# 671    False
# 672    False
# 673    False
# 674    False
# 675    False
# 676    False
# 677    False
# 678    False
# 679    False
# 680    False
# 681    False
# 682    False
# 683    False
# 684    False
# 685    False
# 686    False
# 687    False
# 688    False
# 689    False
# 690    False
# 691    False
# 692    False
# 693    False
# 694    False
# 695    False
# 696    False
# Name: lines, Length: 697, dtype: bool
# friendsscraper/spiders/ep-the one with the birth.csv
# the one with the birth.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 600    False
# 601    False
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# 607    False
# 608    False
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616    False
# 617    False
# 618    False
# 619    False
# 620    False
# 621    False
# Name: lines, Length: 622, dtype: bool
# friendsscraper/spiders/ep-the one in barbados.csv
# the one in barbados.csv
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6        True
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1370    False
# 1371    False
# 1372    False
# 1373    False
# 1374    False
# 1375    False
# 1376    False
# 1377    False
# 1378    False
# 1379    False
# 1380    False
# 1381    False
# 1382    False
# 1383    False
# 1384    False
# 1385    False
# 1386    False
# 1387    False
# 1388    False
# 1389    False
# 1390    False
# 1391    False
# 1392    False
# 1393    False
# 1394    False
# 1395    False
# 1396    False
# 1397    False
# 1398    False
# 1399    False
# Name: lines, Length: 1400, dtype: bool
# friendsscraper/spiders/ep-the one where chandler cant cry.csv
# the one where chandler cant cry.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 553    False
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# 562    False
# 563    False
# 564    False
# 565     True
# 566    False
# 567    False
# 568    False
# 569    False
# 570    False
# 571    False
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# 577    False
# 578    False
# 579    False
# 580    False
# 581    False
# 582    False
# Name: lines, Length: 583, dtype: bool
# friendsscraper/spiders/ep-the one with the inappropriate sister.csv
# the one with the inappropriate sister.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# 577    False
# 578    False
# 579     True
# 580    False
# 581    False
# 582    False
# 583    False
# 584    False
# 585    False
# 586    False
# 587    False
# 588    False
# 589    False
# 590    False
# 591    False
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 600    False
# 601    False
# Name: lines, Length: 602, dtype: bool
# friendsscraper/spiders/ep-the one with the late thanksgiving.csv
# the one with the late thanksgiving.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 804    False
# 805    False
# 806    False
# 807    False
# 808    False
# 809    False
# 810    False
# 811     True
# 812    False
# 813    False
# 814    False
# 815    False
# 816    False
# 817    False
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# 823    False
# 824    False
# 825    False
# 826    False
# 827    False
# 828    False
# 829    False
# 830    False
# 831    False
# 832    False
# 833    False
# Name: lines, Length: 834, dtype: bool
# friendsscraper/spiders/ep-the one where phoebe hates pbs.csv
# the one where phoebe hates pbs.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 477    False
# 478    False
# 479    False
# 480    False
# 481    False
# 482    False
# 483    False
# 484    False
# 485    False
# 486    False
# 487    False
# 488    False
# 489    False
# 490    False
# 491    False
# 492    False
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# 500    False
# 501     True
# 502    False
# 503    False
# 504    False
# 505    False
# 506    False
# Name: lines, Length: 507, dtype: bool
# friendsscraper/spiders/ep-the one with the flashback.csv
# the one with the flashback.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521    False
# 522    False
# 523     True
# 524    False
# 525    False
# 526    False
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# Name: lines, Length: 546, dtype: bool
# friendsscraper/spiders/ep-the one with phoebes uterus.csv
# the one with phoebes uterus.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 431    False
# 432    False
# 433    False
# 434    False
# 435    False
# 436    False
# 437    False
# 438    False
# 439    False
# 440     True
# 441    False
# 442    False
# 443    False
# 444    False
# 445    False
# 446    False
# 447    False
# 448    False
# 449    False
# 450    False
# 451    False
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# 458    False
# 459    False
# 460    False
# Name: lines, Length: 461, dtype: bool
# friendsscraper/spiders/ep-the one with russ.csv
# the one with russ.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 370    False
# 371    False
# 372    False
# 373    False
# 374    False
# 375    False
# 376    False
# 377    False
# 378     True
# 379     True
# 380    False
# 381     True
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390     True
# 391    False
# 392    False
# 393     True
# 394    False
# 395    False
# 396    False
# 397    False
# 398     True
# 399    False
# Name: lines, Length: 400, dtype: bool
# friendsscraper/spiders/ep-the one with rosss wedding parts i and ii.csv
# the one with rosss wedding parts i and ii.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 820    False
# 821    False
# 822    False
# 823    False
# 824    False
# 825    False
# 826    False
# 827    False
# 828    False
# 829    False
# 830    False
# 831    False
# 832    False
# 833    False
# 834    False
# 835    False
# 836    False
# 837    False
# 838    False
# 839    False
# 840    False
# 841    False
# 842    False
# 843    False
# 844    False
# 845    False
# 846    False
# 847    False
# 848    False
# 849    False
# Name: lines, Length: 850, dtype: bool
# friendsscraper/spiders/ep-the one with chandler in a box.csv
# the one with chandler in a box.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28     False
# 29     False
#        ...
# 560    False
# 561    False
# 562    False
# 563    False
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# 569    False
# 570    False
# 571    False
# 572    False
# 573     True
# 574    False
# 575    False
# 576    False
# 577    False
# 578    False
# 579    False
# 580    False
# 581    False
# 582    False
# 583    False
# 584    False
# 585    False
# 586    False
# 587    False
# 588    False
# 589    False
# Name: lines, Length: 590, dtype: bool
# friendsscraper/spiders/ep-the one with the videotape.csv
# the one with the videotape.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 566    False
# 567    False
# 568    False
# 569    False
# 570    False
# 571    False
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# 577    False
# 578    False
# 579    False
# 580    False
# 581    False
# 582    False
# 583     True
# 584    False
# 585    False
# 586    False
# 587    False
# 588    False
# 589    False
# 590    False
# 591    False
# 592    False
# 593    False
# 594    False
# 595    False
# Name: lines, Length: 596, dtype: bool
# friendsscraper/spiders/ep-the one with the stoned guy.csv
# the one with the stoned guy.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 521    False
# 522    False
# 523    False
# 524    False
# 525    False
# 526    False
# 527    False
# 528     True
# 529    False
# 530    False
# 531     True
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# Name: lines, Length: 551, dtype: bool
# friendsscraper/spiders/ep-the one where estelle dies.csv
# the one where estelle dies.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 530    False
# 531    False
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553     True
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# Name: lines, Length: 560, dtype: bool
# friendsscraper/spiders/ep-the one where monica and richard are friends.csv
# the one where monica and richard are friends.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 600     True
# 601    False
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# 607    False
# 608    False
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616    False
# 617    False
# 618    False
# 619    False
# 620    False
# 621    False
# Name: lines, Length: 622, dtype: bool
# friendsscraper/spiders/ep-the one with all the jealousy.csv
# the one with all the jealousy.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 507    False
# 508    False
# 509    False
# 510    False
# 511    False
# 512    False
# 513    False
# 514    False
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521     True
# 522    False
# 523    False
# 524    False
# 525    False
# 526    False
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# Name: lines, Length: 537, dtype: bool
# friendsscraper/spiders/ep-the one with the east german laundry detergent.csv
# the one with the east german laundry detergent.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 503    False
# 504    False
# 505    False
# 506    False
# 507    False
# 508    False
# 509    False
# 510    False
# 511    False
# 512    False
# 513    False
# 514    False
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521    False
# 522    False
# 523    False
# 524    False
# 525    False
# 526    False
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# 532    False
# Name: lines, Length: 533, dtype: bool
# friendsscraper/spiders/ep-the one with all the cheesecakes.csv
# the one with all the cheesecakes.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 579    False
# 580    False
# 581    False
# 582    False
# 583     True
# 584    False
# 585    False
# 586    False
# 587    False
# 588    False
# 589    False
# 590    False
# 591    False
# 592    False
# 593    False
# 594     True
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 600    False
# 601    False
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# 607    False
# 608    False
# Name: lines, Length: 609, dtype: bool
# friendsscraper/spiders/ep-the one with the holiday armadillo.csv
# the one with the holiday armadillo.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 538    False
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553     True
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# 562    False
# 563    False
# 564    False
# 565    False
# 566    False
# 567    False
# Name: lines, Length: 568, dtype: bool
# friendsscraper/spiders/ep-the one that could have been.csv
# the one that could have been.csv
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6        True
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1194    False
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# 1200    False
# 1201    False
# 1202    False
# 1203    False
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# 1214    False
# 1215     True
# 1216    False
# 1217    False
# 1218    False
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223    False
# Name: lines, Length: 1224, dtype: bool
# friendsscraper/spiders/ep-the one with the breast milk.csv
# the one with the breast milk.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 412    False
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# 420    False
# 421    False
# 422    False
# 423    False
# 424    False
# 425    False
# 426    False
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# 433    False
# 434    False
# 435    False
# 436    False
# 437    False
# 438     True
# 439    False
# 440    False
# 441    False
# Name: lines, Length: 442, dtype: bool
# friendsscraper/spiders/ep-the one the morning after.csv
# the one the morning after.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 614    False
# 615    False
# 616    False
# 617    False
# 618    False
# 619    False
# 620    False
# 621    False
# 622    False
# 623    False
# 624     True
# 625    False
# 626    False
# 627    False
# 628    False
# 629    False
# 630    False
# 631     True
# 632    False
# 633    False
# 634    False
# 635    False
# 636    False
# 637    False
# 638     True
# 639    False
# 640    False
# 641    False
# 642    False
# 643    False
# Name: lines, Length: 644, dtype: bool
# friendsscraper/spiders/ep-the one with the birth mother.csv
# the one with the birth mother.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616    False
# 617     True
# 618    False
# 619    False
# 620    False
# 621    False
# 622    False
# 623    False
# 624    False
# 625    False
# 626    False
# 627    False
# 628    False
# 629    False
# 630    False
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# 636    False
# 637    False
# 638    False
# 639    False
# Name: lines, Length: 640, dtype: bool
# friendsscraper/spiders/ep-the one where joey speaks french.csv
# the one where joey speaks french.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 692    False
# 693    False
# 694    False
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# 700    False
# 701    False
# 702    False
# 703    False
# 704    False
# 705    False
# 706    False
# 707    False
# 708    False
# 709    False
# 710    False
# 711    False
# 712    False
# 713    False
# 714    False
# 715    False
# 716    False
# 717    False
# 718    False
# 719    False
# 720    False
# 721    False
# Name: lines, Length: 722, dtype: bool
# friendsscraper/spiders/ep-the one with five steaks and an eggplant.csv
# the one with five steaks and an eggplant.csv
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 269    False
# 270    False
# 271    False
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# 277    False
# 278    False
# 279    False
# 280    False
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# 286    False
# 287    False
# 288    False
# 289    False
# 290    False
# 291    False
# 292    False
# 293    False
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Name: lines, Length: 299, dtype: bool
# friendsscraper/spiders/ep-the one with the vows.csv
# the one with the vows.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 578    False
# 579    False
# 580    False
# 581    False
# 582    False
# 583    False
# 584    False
# 585    False
# 586    False
# 587    False
# 588     True
# 589    False
# 590    False
# 591    False
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 600    False
# 601    False
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# 607    False
# Name: lines, Length: 608, dtype: bool
# friendsscraper/spiders/ep-the one where chandler cant remember which sister.csv
# the one where chandler cant remember which sister.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 617    False
# 618    False
# 619    False
# 620    False
# 621    False
# 622    False
# 623    False
# 624    False
# 625    False
# 626    False
# 627    False
# 628    False
# 629    False
# 630    False
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# 636    False
# 637    False
# 638    False
# 639    False
# 640    False
# 641    False
# 642    False
# 643    False
# 644    False
# 645    False
# 646    False
# Name: lines, Length: 647, dtype: bool
# friendsscraper/spiders/ep-the one with phoebes birthday dinner.csv
# the one with phoebes birthday dinner.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# 506    False
# 507    False
# 508    False
# 509     True
# 510    False
# 511    False
# 512    False
# 513    False
# 514    False
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521    False
# 522    False
# 523    False
# 524    False
# Name: lines, Length: 525, dtype: bool
# friendsscraper/spiders/ep-the one with rachels date.csv
# the one with rachels date.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 641    False
# 642    False
# 643    False
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# 649    False
# 650    False
# 651    False
# 652    False
# 653    False
# 654    False
# 655    False
# 656    False
# 657    False
# 658    False
# 659    False
# 660    False
# 661    False
# 662    False
# 663    False
# 664     True
# 665    False
# 666    False
# 667    False
# 668    False
# 669    False
# 670    False
# Name: lines, Length: 671, dtype: bool
# friendsscraper/spiders/ep-the one with the unagi.csv
# the one with the unagi.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 518    False
# 519    False
# 520    False
# 521    False
# 522    False
# 523    False
# 524    False
# 525    False
# 526     True
# 527    False
# 528    False
# 529     True
# 530    False
# 531    False
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# Name: lines, Length: 548, dtype: bool
# friendsscraper/spiders/ep-the one where nana dies twice.csv
# the one where nana dies twice.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 502    False
# 503    False
# 504    False
# 505    False
# 506    False
# 507    False
# 508    False
# 509    False
# 510    False
# 511    False
# 512    False
# 513    False
# 514    False
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521    False
# 522    False
# 523    False
# 524    False
# 525    False
# 526    False
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# Name: lines, Length: 532, dtype: bool
# friendsscraper/spiders/ep-the one at the beach.csv
# the one at the beach.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616    False
# 617    False
# 618    False
# 619    False
# 620    False
# 621    False
# 622    False
# 623    False
# 624    False
# 625    False
# 626     True
# 627    False
# 628    False
# 629    False
# 630     True
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# 636    False
# 637    False
# 638    False
# 639    False
# 640    False
# Name: lines, Length: 641, dtype: bool
# friendsscraper/spiders/ep-the one with barry and mindys wedding.csv
# the one with barry and mindys wedding.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 440    False
# 441     True
# 442    False
# 443    False
# 444    False
# 445    False
# 446    False
# 447    False
# 448    False
# 449    False
# 450    False
# 451    False
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# 458    False
# 459    False
# 460    False
# 461    False
# 462    False
# 463     True
# 464    False
# 465    False
# 466    False
# 467    False
# 468    False
# 469    False
# Name: lines, Length: 470, dtype: bool
# friendsscraper/spiders/ep-the one hundredth.csv
# the one hundredth.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 570    False
# 571    False
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# 577    False
# 578    False
# 579    False
# 580    False
# 581    False
# 582     True
# 583    False
# 584    False
# 585    False
# 586    False
# 587    False
# 588    False
# 589    False
# 590    False
# 591    False
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# Name: lines, Length: 600, dtype: bool
# friendsscraper/spiders/ep-the one with all the kissing.csv
# the one with all the kissing.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# 555     True
# 556    False
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# 562    False
# 563    False
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# 569    False
# 570    False
# 571    False
# Name: lines, Length: 572, dtype: bool
# friendsscraper/spiders/ep-the one with rachels sister.csv
# the one with rachels sister.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# 562    False
# 563    False
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# 569    False
# 570    False
# 571    False
# 572    False
# 573    False
# 574    False
# 575    False
# Name: lines, Length: 576, dtype: bool
# friendsscraper/spiders/ep-the one where eddie wont go.csv
# the one where eddie wont go.csv
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 621    False
# 622    False
# 623     True
# 624    False
# 625    False
# 626    False
# 627    False
# 628    False
# 629    False
# 630    False
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# 636    False
# 637     True
# 638    False
# 639    False
# 640    False
# 641    False
# 642    False
# 643    False
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# 649    False
# 650    False
# Name: lines, Length: 651, dtype: bool
# friendsscraper/spiders/ep-the one with the soap opera party.csv
# the one with the soap opera party.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 635    False
# 636    False
# 637    False
# 638    False
# 639    False
# 640    False
# 641    False
# 642    False
# 643    False
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# 649    False
# 650    False
# 651    False
# 652    False
# 653    False
# 654     True
# 655    False
# 656    False
# 657    False
# 658    False
# 659    False
# 660    False
# 661    False
# 662    False
# 663    False
# 664    False
# Name: lines, Length: 665, dtype: bool
# friendsscraper/spiders/ep-the one with princess consuela.csv
# the one with princess consuela.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 729    False
# 730    False
# 731    False
# 732    False
# 733    False
# 734    False
# 735    False
# 736    False
# 737    False
# 738    False
# 739    False
# 740    False
# 741    False
# 742    False
# 743    False
# 744    False
# 745    False
# 746    False
# 747    False
# 748    False
# 749    False
# 750     True
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# 756    False
# 757    False
# 758    False
# Name: lines, Length: 759, dtype: bool
# friendsscraper/spiders/ep-the one with joeys new brain.csv
# the one with joeys new brain.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 704    False
# 705    False
# 706    False
# 707    False
# 708    False
# 709    False
# 710    False
# 711    False
# 712    False
# 713     True
# 714    False
# 715    False
# 716    False
# 717    False
# 718    False
# 719    False
# 720    False
# 721    False
# 722    False
# 723    False
# 724    False
# 725    False
# 726    False
# 727    False
# 728    False
# 729    False
# 730    False
# 731    False
# 732    False
# 733    False
# Name: lines, Length: 734, dtype: bool
# friendsscraper/spiders/ep-the one with the metaphorical tunnel.csv
# the one with the metaphorical tunnel.csv
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# 505      NaN
# 506    False
# 507    False
# 508    False
# 509    False
# 510      NaN
# 511    False
# 512    False
# 513    False
# 514    False
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# 520    False
# 521    False
# 522     True
# 523    False
# 524    False
# 525    False
# 526    False
# 527    False
# 528    False
# 529    False
# Name: lines, Length: 530, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-277-8c34cf17bc52> in <module>
#       2     if 'ep-' in episode:
#       3         path = 'friendsscraper/spiders/' + episode
# ----> 4         raw_lines, ep_title = read_file(path)
#       5         df = process_script(raw_lines, ep_title)
#       6         ep_title = ep_title.lower()
#
# <ipython-input-276-6ac2999645f0> in read_file(file_path)
#      40     # Remove rows that will not be included in analysis
#      41     print(df.lines.str.contains('[', regex=False))
# ---> 42     script = df[df.lines.str.contains('[', regex=False).idxmax():]
#      43
#      44     script = script.applymap(remove_returns)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    1783         """
#    1784         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 1785         i = nanops.nanargmax(com._values_from_object(self), skipna=skipna)
#    1786         if i == -1:
#    1787             return np.nan
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      72             if any(self.check(obj) for obj in obj_iter):
#      73                 msg = 'reduction operation {name!r} not allowed for this dtype'
# ---> 74                 raise TypeError(msg.format(name=f.__name__.replace('nan', '')))
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
#
# TypeError: reduction operation 'argmax' not allowed for this dtype

# %%
#ex = pd.read_csv('friendsscraper/spiders/processed_ep_the one where chandler crosses a line.csv', encoding='utf-8')
#ex.head(20)
ex_raw = pd.read_csv('friendsscraper/spiders/ep-the one with the metaphorical tunnel.csv')
ex_raw.tail(30)
# Out:
#                   the one with the metaphorical tunnel
# 499                                              Ross:
# 500   There was no song. (to Monica) There was no s...
# 501                                            Monica:
# 502                                         (singing)
# 503                                          I am Bea.
# 504                                                NaN
# 505                                              Ross:
# 506                                              Okay.
# 507                                            Monica:
# 508                                       I drink tea.
# 509                                                NaN
# 510                                              Ross:
# 511   Okay, thats, thats enough. (retreats to the b...
# 512                                            Monica:
# 513                                               ....
# 514                       Wont you, wont you, wont you
# 515                                              ....
# 516                                              Ross:
# 517   (coming out of the bathroom) Wont you dance a...
# 518                                            Monica:
# 519   A-ha!!! (they all start laughing, as Ross hid...
# 520                                    Closing Credits
# 521  [Scene: Its an old home movie of the Gellers b...
# 522                                             Young
# 523                                              Ross:
# 524   (singing) I am Bea. I drink tea. Wont you dan...
# 525                                              Young
# 526                                            Monica:
# 527   (entering the shot) Ross!!! (starts to wipe u...
# 528                                                End

# %%
raw_lines, ep_title = read_file("friendsscraper/spiders/ep-the last one.csv")
last_proc = process_script(raw_lines, ep_title)
# Out:
# friendsscraper/spiders/ep-the last one.csv
# the last one.csv

# %%
last_proc.head(50)
# Out:
#          episode                              scene  \
# 0   the last one     monica and chandlers apartment
# 1   the last one     monica and chandlers apartment
# 2   the last one     monica and chandlers apartment
# 3   the last one     monica and chandlers apartment
# 4   the last one     monica and chandlers apartment
# 5   the last one     monica and chandlers apartment
# 6   the last one     monica and chandlers apartment
# 7   the last one     monica and chandlers apartment
# 8   the last one     monica and chandlers apartment
# 9   the last one     monica and chandlers apartment
# 10  the last one     monica and chandlers apartment
# 11  the last one     monica and chandlers apartment
# 12  the last one     monica and chandlers apartment
# 13  the last one                      rosss bedroom
# 14  the last one                      rosss bedroom
# 15  the last one                      rosss bedroom
# 16  the last one                      rosss bedroom
# 17  the last one                      rosss bedroom
# 18  the last one                      rosss bedroom
# 19  the last one                      rosss bedroom
# 20  the last one                      rosss bedroom
# 21  the last one                      rosss bedroom
# 22  the last one                      rosss bedroom
# 23  the last one  the delivery room at the hospital
# 24  the last one  the delivery room at the hospital
# 25  the last one  the delivery room at the hospital
# 26  the last one  the delivery room at the hospital
# 27  the last one  the delivery room at the hospital
# 28  the last one  the delivery room at the hospital
# 29  the last one  the delivery room at the hospital
# 30  the last one  the delivery room at the hospital
# 31  the last one  the delivery room at the hospital
# 32  the last one  the delivery room at the hospital
# 33  the last one  the delivery room at the hospital
# 34  the last one  the delivery room at the hospital
# 35  the last one  the delivery room at the hospital
# 36  the last one  the delivery room at the hospital
# 37  the last one  the delivery room at the hospital
# 38  the last one  the delivery room at the hospital
# 39  the last one  the delivery room at the hospital
# 40  the last one  the delivery room at the hospital
# 41  the last one  the delivery room at the hospital
# 42  the last one  the delivery room at the hospital
# 43  the last one  the delivery room at the hospital
# 44  the last one  the delivery room at the hospital
# 45  the last one         joey and rachels apartment
# 46  the last one         joey and rachels apartment
# 47  the last one         joey and rachels apartment
# 48  the last one         joey and rachels apartment
# 49  the last one         joey and rachels apartment
#
#                                             direction           characters  \
# 0                                                  vo                 None
# 1                                                None  jennifer aniston vo
# 2                                                None               monica
# 3                                                None                erica
# 4                                                None               monica
# 5                                                None             chandler
# 6                                                None               monica
# 7                                                None             chandler
# 8   cut to rosss apartment ross and rachel are the...                 None
# 9                                                None               rachel
# 10                                               None                 ross
# 11                                               None               rachel
# 12  he walks over and kisses her they pull back ra...                 None
# 13                                               None                 ross
# 14                                               None               rachel
# 15                                               None                 ross
# 16                                               None               rachel
# 17                                               None                 ross
# 18                                               None               rachel
# 19                                               None                 ross
# 20                                               None               rachel
# 21                                          they kiss                 None
# 22                                               None                 None
# 23                                               None               monica
# 24                                               None             chandler
# 25                                               None               monica
# 26                                               None                erica
# 27                                               None               monica
# 28                                               None             chandler
# 29                                               None               monica
# 30                                               None             chandler
# 31                                               None               monica
# 32                                               None             chandler
# 33                                               None               monica
# 34                                               None             chandler
# 35                                               None               monica
# 36                                               None             chandler
# 37  monica leaves and chandler closes the door eri...                 None
# 38                                               None             chandler
# 39                                               None                erica
# 40                                               None             chandler
# 41                                               None                erica
# 42                                               None             chandler
# 43             erica just looks at him like hes crazy                 None
# 44                                               None             chandler
# 45                                               None               phoebe
# 46                                               None                 joey
# 47                                               None               phoebe
# 48                                               None                 joey
# 49                                               None               phoebe
#
#                                              dialogue
# 0                                    jennifer aniston
# 1                               previously on friends
# 2                                  erica are you okay
# 3   yeah you know maybe i ate too much i keep gett...
# 4                                           oh my god
# 5               relax well just get her some antacids
# 6         she doesnt have a stomachache shes in labor
# 7                                           oh my god
# 8                                                None
# 9   so if you think i didnt say goodbye to you bec...
# 10                                               rach
# 11                                               what
# 12                                               None
# 13                                                hey
# 14             shh go back to sleep i have to go home
# 15                                oh this was amazing
# 16         it really was youve learned some new moves
# 17  yeah well this guy at work gave me sex for dum...
# 18                                                 ah
# 19                                  whos laughing now
# 20                                             i know
# 21                                               None
# 22                                    opening credits
# 23                       breathe breathe breathe good
# 24                        next time can i say breathe
# 25  no last time you said it like dracula and it s...
# 26                                         no im okay
# 27                          alright ill be right back
# 28                                where are you going
# 29                                to use the bathroom
# 30                   you cant leave me alone with her
# 31                                               what
# 32  this is exactly the kind of social situation t...
# 33  what kind of social situation are you comforta...
# 34  its just that weve never spent any time you kn...
# 35  youll be fine nah you wont but ill be back in ...
# 36                                               okay
# 37                                               None
# 38                     so ah any plans for the summer
# 39                       i dont know maybe churchcamp
# 40  hah may not wanna mention this so you ever won...
# 41                                               what
# 42  well its just interesting you know because no ...
# 43                                               None
# 44  one of lifes great unanswerable questions i me...
# 45                                            morning
# 46                                                hey
# 47                                         whats that
# 48  its my housewarming present for monica and cha...
# 49                          its a baby chick and duck
