# %%
import pandas as pd
import numpy as np
import re
import string
import os
import csv
import math

def clean_line(line):
    if line == '' or line == None:
        return 'delete'
    elif line[0] == '[':
        return 'scene'
    elif line[0] == '(' and line[-1] == ')': 
        return 'direction'
    elif ':' in line:
        return 'character'
    elif line == "Opening Credits":
        return 'credits'
    elif line == 'Commercial Break':
        return 'commercials'
    elif line == 'End':
        return 'end'
    else:
        return 'dialogue'

def remove_returns(line):
    if line != None and str(line) != 'nan':
        return line.replace('\n', '')

def read_file(file_path):
    df = pd.read_csv(file_path, header=None, encoding="utf-8")
    df.columns = ['lines']
    print(df.head(20))
            
    print(file_path)
    # Get episode title
    
    title = file_path.replace('friendsscraper/spiders/ep-', '')
    
    print(title)
    
    # Remove rows that will not be included in analysis
    index_list = df.lines.str.contains('[', regex=False)
    index_list = pd.Series([x for x in index_list if str(x) != 'nan'])
    script = df[index_list.idxmax():]
    
    script = script.applymap(remove_returns)
    
    script['clean_code'] = list(map(clean_line, script['lines']))
    script.set_index('clean_code', inplace=True)
    
    if 'delete' in script.index:
        script.drop('delete', axis=0, inplace=True)
    
    lines = script['lines'].values
    
    return (lines, title) #, writers)

def clean_scenes(scene):
    if scene not in [None, 'Opening Credits', 'End', 'Commercial Break']:
        return scene.replace('[Scene:', '').replace(']', '').replace(')', '').replace('\xa0', '').strip()
    else:
        return scene
    
def dir_from_scene(scene):
    if scene not in [None, 'Opening Credits', 'End', 'Commercial Break']:
        search = {',', '.'}
        delim_index = next((i for i, ch in enumerate(scene) if ch in search), None)
        if delim_index == None:
            delim = ','
        else:
            delim = scene[delim_index]
        if scene.split(delim)[1:] != '':
            #print(scene.split(delim))
            #print(' '.join(scene.split(delim)[1:]))
            return ' '.join(scene.split(delim)[1:])
        else: 
            return None
    else: 
        return None

def isolate_scene(scene):
    if scene not in [None, 'Opening Credits', 'End', 'Commercial Break']:
        search = {',', '.'}
        delim_index = next((i for i, ch in enumerate(scene) if ch in search), None)
        if delim_index == None:
            delim = ','
        else:
            delim = scene[delim_index]
        return scene.split(delim)[0]
    else:
        return scene
    
def clean_directions(direction):
    if direction != None:
        return direction.replace('(', '').replace(')', '')
    else:
        return direction
    
def text_clean(line):
    if line != None and type(line) != list:
        return line.lower().strip().translate(str.maketrans('', '', string.punctuation))
    else: 
        return line

def process_script(lines, title): #, writers):

    dialogue = []
    character = []
    scene = []
    episode = []
    direction = []
    # written_by = []
    
    def update_lists(dia, char, scn, ep, direct): #, wrt):
        dialogue.append(dia)
        character.append(char)
        scene.append(scn)
        episode.append(ep.rstrip('csv'))
        direction.append(direct)
        #written_by.append(wrt)

    current_scene = None
    current_dialogue = None
    current_character = None
    colon_in_front = False

    i = 0 

    while i < len(lines):
        if 'Scene:' in lines[i]:
            current_scene = lines[i]
            current_dialogue = None
            current_character = None

        elif (lines[i][0] == '(') or ('Scene:' not in lines[i] and (lines[i][0] == '[' and lines[i][-1] == ']')):
            if current_scene == None:
                current_scene = lines[i]
                current_character = None
                current_dialogue = None
            else:
                current_character = None
                current_dialogue = None
                update_lists(current_dialogue, current_character, current_scene, title, lines[i])# , writers)


        elif ':' in lines[i]:
            if lines[i][0] == ':':
                current_character = lines[i-1].strip()
                current_dialogue = lines[i].strip(':')
                colon_in_front = True
            elif lines[i][-1] != ':':
                current_character = lines[i].split(':')[0]
                current_dialogue = lines[i].split(':')[1]
            else:
                current_character = lines[i].strip(':')
                current_dialogue = None
                
            if lines[i-1].strip()[-3:] == 'and':
                current_character = lines[i-1] + ' ' + current_character
            
        elif (lines[i] == 'Opening Credits' or lines[i] == 'Commercial Break') or lines[i] == 'End':
            current_character = None
            current_dialogue = None  
            update_lists(current_dialogue, current_character, lines[i], title, None) #, writers)
       
        else:
            if current_dialogue == None:
                current_dialogue = lines[i]
            else:
                current_dialogue += ' ' + lines[i]
        
        if i + 1 < len(lines) and current_dialogue != None and (lines[i+1][0] == '[' or (lines[i+1][0] == '(' and lines[i+1][-1] == ')') or ':' in lines[i+1] or lines[i+1] == 'Opening Credits' or lines[i+1] == 'Commercial Break' or lines[i+1] == 'End'):
            
            if colon_in_front:
                current_dialogue = current_dialogue.lower().strip()
                if (current_dialogue.endswith('monica') or current_dialogue.endswith('doctor')) or (current_dialogue.endswith('rachel') or current_dialogue.endswith('phoebe')):
                    current_dialogue = current_dialogue[:-6]
                elif current_dialogue.endswith('ross') or current_dialogue.endswith('joey'):
                    current_dialogue = current_dialogue[:-4]
                elif current_dialogue.endswith('chandler'):
                    current_dialogue = current_dialogue[:-8]
                elif current_dialogue.endswith('erica'):
                    current_dialogue = current_dialogue[:-5]
                elif current_dialogue.endswith('gate attendant #1') or current_dialogue.endswith('gate attendant #2'):
                    current_dialogue = current_dialogue[:-17]
                elif (current_dialogue.endswith('ticket agent') or current_dialogue.endswith('passenger #1')) or (current_dialogue.endswith('passenger #2') or current_dialogue.endswith('passenger #3')):
                    current_dialogue = current_dialogue[:-12]
                elif current_dialogue.endswith('air stewerdess'):
                    current_dialogue = current_dialogue[:-14]
                
                if current_dialogue != '':
                    update_lists(current_dialogue, current_character, current_scene, title, None) #, writers)
            else:
                update_lists(current_dialogue, current_character, current_scene, title, None) #, writers)


        i += 1
    
    script_df = pd.DataFrame(list(zip(episode, scene, direction, character, dialogue)), columns=['episode', 'scene', 'direction', 'characters', 'dialogue'])
    
    script_df['scene']  = list(map(clean_scenes, script_df['scene']))
    
    for i in range(len(script_df)):
        if i == 0 or script_df['scene'][i] != script_df['scene'][i-1]:
            if script_df['direction'][0] == '' or script_df['direction'][0] == None:
                script_df['direction'][i] = dir_from_scene(script_df['scene'][i])
            elif script_df['direction'][i] != None and dir_from_scene(script_df['scene'][i]) != None:
                script_df['direction'][i] = script_df['direction'][i] + ' ' + dir_from_scene(script_df['scene'][i])
            #print(dir_from_scene(script_df['scene'][i]))
            
    for i in range(len(script_df)):
        
        if script_df['dialogue'][i] != None and '(' in script_df['dialogue'][i]:
            script_df['direction'][i] = script_df['dialogue'][i][script_df['dialogue'][i].find("(") + 1:script_df['dialogue'][i].find(")")]
            script_df['dialogue'][i] = re.sub("[\(].*?[\)]", '', script_df['dialogue'][i])

        
    script_df['scene'] = list(map(isolate_scene, script_df['scene']))
    script_df['direction'] = list(map(clean_directions, script_df['direction']))
    
    return script_df.applymap(text_clean)

# %%
for episode in os.listdir('friendsscraper/spiders/'):
    if 'ep-' in episode: 
        path = 'friendsscraper/spiders/' + episode
        raw_lines, ep_title = read_file(path)
        df = process_script(raw_lines, ep_title)
        ep_title = ep_title.lower()
        df.to_csv('friendsscraper/spiders/processed_ep_%s' % ep_title, index=False)
# Out:
# friendsscraper/spiders/ep-the one with ross tan.csv
# the one with ross tan.csv
# friendsscraper/spiders/ep-the one with the screamer.csv
# the one with the screamer.csv
# friendsscraper/spiders/ep-the one with the sonogram at the end.csv
# the one with the sonogram at the end.csv
# friendsscraper/spiders/ep-the one with phoebes wedding.csv
# the one with phoebes wedding.csv
# friendsscraper/spiders/ep-the one with the fake monica.csv
# the one with the fake monica.csv
# friendsscraper/spiders/ep-the one with joeys fridge.csv
# the one with joeys fridge.csv
# friendsscraper/spiders/ep-the one with the birth.csv
# the one with the birth.csv
# friendsscraper/spiders/ep-the one in barbados.csv
# the one in barbados.csv
# friendsscraper/spiders/ep-the one where chandler cant cry.csv
# the one where chandler cant cry.csv
# friendsscraper/spiders/ep-the one with the inappropriate sister.csv
# the one with the inappropriate sister.csv
# friendsscraper/spiders/ep-the one with the late thanksgiving.csv
# the one with the late thanksgiving.csv
# friendsscraper/spiders/ep-the one where phoebe hates pbs.csv
# the one where phoebe hates pbs.csv
# friendsscraper/spiders/ep-the one with the flashback.csv
# the one with the flashback.csv
# friendsscraper/spiders/ep-the one with phoebes uterus.csv
# the one with phoebes uterus.csv
# friendsscraper/spiders/ep-the one with russ.csv
# the one with russ.csv
# friendsscraper/spiders/ep-the one with rosss wedding parts i and ii.csv
# the one with rosss wedding parts i and ii.csv
# friendsscraper/spiders/ep-the one with chandler in a box.csv
# the one with chandler in a box.csv
# friendsscraper/spiders/ep-the one with the videotape.csv
# the one with the videotape.csv
# friendsscraper/spiders/ep-the one with the stoned guy.csv
# the one with the stoned guy.csv
# friendsscraper/spiders/ep-the one where estelle dies.csv
# the one where estelle dies.csv
# friendsscraper/spiders/ep-the one where monica and richard are friends.csv
# the one where monica and richard are friends.csv
# friendsscraper/spiders/ep-the one with all the jealousy.csv
# the one with all the jealousy.csv
# friendsscraper/spiders/ep-the one with the east german laundry detergent.csv
# the one with the east german laundry detergent.csv
# friendsscraper/spiders/ep-the one with all the cheesecakes.csv
# the one with all the cheesecakes.csv
# friendsscraper/spiders/ep-the one with the holiday armadillo.csv
# the one with the holiday armadillo.csv
# friendsscraper/spiders/ep-the one that could have been.csv
# the one that could have been.csv
# friendsscraper/spiders/ep-the one with the breast milk.csv
# the one with the breast milk.csv
# friendsscraper/spiders/ep-the one the morning after.csv
# the one the morning after.csv
# friendsscraper/spiders/ep-the one with the birth mother.csv
# the one with the birth mother.csv
# friendsscraper/spiders/ep-the one where joey speaks french.csv
# the one where joey speaks french.csv
# friendsscraper/spiders/ep-the one with five steaks and an eggplant.csv
# the one with five steaks and an eggplant.csv
# friendsscraper/spiders/ep-the one with the vows.csv
# the one with the vows.csv
# friendsscraper/spiders/ep-the one where chandler cant remember which sister.csv
# the one where chandler cant remember which sister.csv
# friendsscraper/spiders/ep-the one with phoebes birthday dinner.csv
# the one with phoebes birthday dinner.csv
# friendsscraper/spiders/ep-the one with rachels date.csv
# the one with rachels date.csv
# friendsscraper/spiders/ep-the one with the unagi.csv
# the one with the unagi.csv
# friendsscraper/spiders/ep-the one where nana dies twice.csv
# the one where nana dies twice.csv
# friendsscraper/spiders/ep-the one at the beach.csv
# the one at the beach.csv
# friendsscraper/spiders/ep-the one with barry and mindys wedding.csv
# the one with barry and mindys wedding.csv
# friendsscraper/spiders/ep-the one hundredth.csv
# the one hundredth.csv
# friendsscraper/spiders/ep-the one with all the kissing.csv
# the one with all the kissing.csv
# friendsscraper/spiders/ep-the one with rachels sister.csv
# the one with rachels sister.csv
# friendsscraper/spiders/ep-the one where eddie wont go.csv
# the one where eddie wont go.csv
# friendsscraper/spiders/ep-the one with the soap opera party.csv
# the one with the soap opera party.csv
# friendsscraper/spiders/ep-the one with princess consuela.csv
# the one with princess consuela.csv
# friendsscraper/spiders/ep-the one with joeys new brain.csv
# the one with joeys new brain.csv
# friendsscraper/spiders/ep-the one with the metaphorical tunnel.csv
# the one with the metaphorical tunnel.csv
# friendsscraper/spiders/ep-the one with rosss teeth.csv
# the one with rosss teeth.csv
# friendsscraper/spiders/ep-the one with the hypnosis tape.csv
# the one with the hypnosis tape.csv
# friendsscraper/spiders/ep-the one with the jellyfish.csv
# the one with the jellyfish.csv
# friendsscraper/spiders/ep-the one with rosss denial.csv
# the one with rosss denial.csv
# friendsscraper/spiders/ep-the one where ross hugs rachel.csv
# the one where ross hugs rachel.csv
# friendsscraper/spiders/ep-the one with two parts part 2.csv
# the one with two parts part 2.csv
# friendsscraper/spiders/ep-the one with the princess leia fantasy.csv
# the one with the princess leia fantasy.csv
# friendsscraper/spiders/ep-the one where chandler crosses a line.csv
# the one where chandler crosses a line.csv
# friendsscraper/spiders/ep-the one with the evil orthodontist.csv
# the one with the evil orthodontist.csv
# friendsscraper/spiders/ep-the one with the secret closet.csv
# the one with the secret closet.csv
# friendsscraper/spiders/ep-the one with ross new girlfriend.csv
# the one with ross new girlfriend.csv
# friendsscraper/spiders/ep-the one with chandlers dad.csv
# the one with chandlers dad.csv
# friendsscraper/spiders/ep-the one with the two bullies.csv
# the one with the two bullies.csv
# friendsscraper/spiders/ep-the one with the yeti.csv
# the one with the yeti.csv
# friendsscraper/spiders/ep-the one where joey dates rachel.csv
# the one where joey dates rachel.csv
# friendsscraper/spiders/ep-the one with the stain.csv
# the one with the stain.csv
# friendsscraper/spiders/ep-the one with two parts part 1.csv
# the one with two parts part 1.csv
# friendsscraper/spiders/ep-the one with the tiny tshirt.csv
# the one with the tiny tshirt.csv
# friendsscraper/spiders/ep-the one with frank jr.csv
# the one with frank jr.csv
# friendsscraper/spiders/ep-the one with rosss thing.csv
# the one with rosss thing.csv
# friendsscraper/spiders/ep-the one where chandler gets caught.csv
# the one where chandler gets caught.csv
# friendsscraper/spiders/ep-the one with monicas boots.csv
# the one with monicas boots.csv
# friendsscraper/spiders/ep-the one where ross got high.csv
# the one where ross got high.csv
# friendsscraper/spiders/ep-the one with the memorial service.csv
# the one with the memorial service.csv
# friendsscraper/spiders/ep-the one with the pediatrician.csv
# the one with the pediatrician.csv
# friendsscraper/spiders/ep-the one with phoebes husband.csv
# the one with phoebes husband.csv
# friendsscraper/spiders/ep-the one where ross meets elizabeths dad.csv
# the one where ross meets elizabeths dad.csv
# friendsscraper/spiders/ep-the one with the two parties.csv
# the one with the two parties.csv
# friendsscraper/spiders/ep-the one where rachel tells.csv
# the one where rachel tells.csv
# friendsscraper/spiders/ep-the one with the baby shower.csv
# the one with the baby shower.csv
# friendsscraper/spiders/ep-the one with the ballroom dancing.csv
# the one with the ballroom dancing.csv
# friendsscraper/spiders/ep-the one with phoebes dad.csv
# the one with phoebes dad.csv
# friendsscraper/spiders/ep-the one where ross and rachel take a break.csv
# the one where ross and rachel take a break.csv
# friendsscraper/spiders/ep-the one with the prom video.csv
# the one with the prom video.csv
# friendsscraper/spiders/ep-the one where no one proposes.csv
# the one where no one proposes.csv
# friendsscraper/spiders/ep-the one with the ring.csv
# the one with the ring.csv
# friendsscraper/spiders/ep-the one where monica gets a new roommate the pilotthe uncut version.csv
# the one where monica gets a new roommate the pilotthe uncut version.csv
# friendsscraper/spiders/ep-the one where ross is fine.csv
# the one where ross is fine.csv
# friendsscraper/spiders/ep-the one with phoebes expartner.csv
# the one with phoebes expartner.csv
# friendsscraper/spiders/ep-the one where ross cant flirt.csv
# the one where ross cant flirt.csv
# friendsscraper/spiders/ep-the one with mrs bing.csv
# the one with mrs bing.csv
# friendsscraper/spiders/ep-the one with the fake party.csv
# the one with the fake party.csv
# friendsscraper/spiders/ep-the one with the cuffs.csv
# the one with the cuffs.csv
# friendsscraper/spiders/ep-the one with rachels assistant.csv
# the one with rachels assistant.csv
# friendsscraper/spiders/ep-the one with the thumb.csv
# the one with the thumb.csv
# friendsscraper/spiders/ep-the one with the truth about london.csv
# the one with the truth about london.csv
# friendsscraper/spiders/ep-the one with the engagement picture.csv
# the one with the engagement picture.csv
# friendsscraper/spiders/ep-the one with joeys new girlfriend.csv
# the one with joeys new girlfriend.csv
# friendsscraper/spiders/ep-the one with monicas thunder.csv
# the one with monicas thunder.csv
# friendsscraper/spiders/ep-the one with the baby on the bus.csv
# the one with the baby on the bus.csv
# friendsscraper/spiders/ep-the one with rachels other sister.csv
# the one with rachels other sister.csv
# friendsscraper/spiders/ep-the one where dr remore dies.csv
# the one where dr remore dies.csv
# friendsscraper/spiders/ep-the one with joeys porsche.csv
# the one with joeys porsche.csv
# friendsscraper/spiders/ep-the one with the male nanny 200th episode.csv
# the one with the male nanny 200th episode.csv
# friendsscraper/spiders/ep-the one with the dollhouse.csv
# the one with the dollhouse.csv
# friendsscraper/spiders/ep-the one where joey loses his insurance.csv
# the one where joey loses his insurance.csv
# friendsscraper/spiders/ep-the one where ross moves in.csv
# the one where ross moves in.csv
# friendsscraper/spiders/ep-the one with joeys dirty day.csv
# the one with joeys dirty day.csv
# friendsscraper/spiders/ep-the one with the boobies.csv
# the one with the boobies.csv
# friendsscraper/spiders/ep-the one where they all turn thirty.csv
# the one where they all turn thirty.csv
# friendsscraper/spiders/ep-the one with the dirty girl.csv
# the one with the dirty girl.csv
# friendsscraper/spiders/ep-the one with the list.csv
# the one with the list.csv
# friendsscraper/spiders/ep-the one where theyre gonna party.csv
# the one where theyre gonna party.csv
# friendsscraper/spiders/ep-the one with the tea leaves.csv
# the one with the tea leaves.csv
# friendsscraper/spiders/ep-the one where rosita dies.csv
# the one where rosita dies.csv
# friendsscraper/spiders/ep-the one with the giant poking device.csv
# the one with the giant poking device.csv
# friendsscraper/spiders/ep-the one with the red sweater.csv
# the one with the red sweater.csv
# friendsscraper/spiders/ep-the one with the invitation.csv
# the one with the invitation.csv
# friendsscraper/spiders/ep-the one where underdog gets away.csv
# the one where underdog gets away.csv
# friendsscraper/spiders/ep-the one with christmas in tulsa.csv
# the one with christmas in tulsa.csv
# friendsscraper/spiders/ep-the one where emma cries.csv
# the one where emma cries.csv
# friendsscraper/spiders/ep-the one with rachels new dress.csv
# the one with rachels new dress.csv
# friendsscraper/spiders/ep-the one with chandler and monicas wedding.csv
# the one with chandler and monicas wedding.csv
# friendsscraper/spiders/ep-the one in massapequa.csv
# the one in massapequa.csv
# friendsscraper/spiders/ep-the one with the rumor.csv
# the one with the rumor.csv
# friendsscraper/spiders/ep-the one with joeys interview.csv
# the one with joeys interview.csv
# friendsscraper/spiders/ep-the one with mac and cheese.csv
# the one with mac and cheese.csv
# friendsscraper/spiders/ep-the one with rachels going away party.csv
# the one with rachels going away party.csv
# friendsscraper/spiders/ep-the one with the ride along.csv
# the one with the ride along.csv
# friendsscraper/spiders/ep-the one with the jam.csv
# the one with the jam.csv
# friendsscraper/spiders/ep-the one with the girl from poughkeepsie.csv
# the one with the girl from poughkeepsie.csv
# friendsscraper/spiders/ep-the one with rosss book.csv
# the one with rosss book.csv
# friendsscraper/spiders/ep-the one where ross dates a student.csv
# the one where ross dates a student.csv
# friendsscraper/spiders/ep-the one after i do.csv
# the one after i do.csv
# friendsscraper/spiders/ep-the one where chandler takes a bath.csv
# the one where chandler takes a bath.csv
# friendsscraper/spiders/ep-the one with a cop.csv
# the one with a cop.csv
# friendsscraper/spiders/ep-the one with joeys bag.csv
# the one with joeys bag.csv
# friendsscraper/spiders/ep-the one with the blind dates.csv
# the one with the blind dates.csv
# friendsscraper/spiders/ep-the one where rachels sister babysits.csv
# the one where rachels sister babysits.csv
# friendsscraper/spiders/ep-the one where joey moves out.csv
# the one where joey moves out.csv
# friendsscraper/spiders/ep-the one with rachels crush.csv
# the one with rachels crush.csv
# friendsscraper/spiders/ep-the one with rosss inappropriate song.csv
# the one with rosss inappropriate song.csv
# friendsscraper/spiders/ep-the one with the donor.csv
# the one with the donor.csv
# friendsscraper/spiders/ep-the one with ross big step forward.csv
# the one with ross big step forward.csv
# friendsscraper/spiders/ep-the one with the butt.csv
# the one with the butt.csv
# friendsscraper/spiders/ep-the one with the candy hearts.csv
# the one with the candy hearts.csv
# friendsscraper/spiders/ep-the one where theyre up all night.csv
# the one where theyre up all night.csv
# friendsscraper/spiders/ep-the one with the stripper.csv
# the one with the stripper.csv
# friendsscraper/spiders/ep-the one where the monkey gets away.csv
# the one where the monkey gets away.csv
# friendsscraper/spiders/ep-the one where ross finds out.csv
# the one where ross finds out.csv
# friendsscraper/spiders/ep-the one where rachel quits.csv
# the one where rachel quits.csv
# friendsscraper/spiders/ep-the one with the cheap wedding dress.csv
# the one with the cheap wedding dress.csv
# friendsscraper/spiders/ep-the one with rachels book.csv
# the one with rachels book.csv
# friendsscraper/spiders/ep-the one with the fertility test.csv
# the one with the fertility test.csv
# friendsscraper/spiders/ep-the one with rachels big kiss.csv
# the one with rachels big kiss.csv
# friendsscraper/spiders/ep-the one with a chick and a duck.csv
# the one with a chick and a duck.csv
# friendsscraper/spiders/ep-the one where phoebe runs.csv
# the one where phoebe runs.csv
# friendsscraper/spiders/ep-the one where the stripper cries.csv
# the one where the stripper cries.csv
# friendsscraper/spiders/ep-the one with the apothecary table.csv
# the one with the apothecary table.csv
# friendsscraper/spiders/ep-the one with all the wedding dresses.csv
# the one with all the wedding dresses.csv
# friendsscraper/spiders/ep-the one with rosss sandwich.csv
# the one with rosss sandwich.csv
# friendsscraper/spiders/ep-the one after the superbowl.csv
# the one after the superbowl.csv
# friendsscraper/spiders/ep-the one with the worst best man ever.csv
# the one with the worst best man ever.csv
# friendsscraper/spiders/ep-the one with the monkey.csv
# the one with the monkey.csv
# friendsscraper/spiders/ep-the one with all the resolutions.csv
# the one with all the resolutions.csv
# friendsscraper/spiders/ep-the one with the thanksgiving flashbacks.csv
# the one with the thanksgiving flashbacks.csv
# friendsscraper/spiders/ep-the one with all the kips.csv
# the one with all the kips.csv
# friendsscraper/spiders/ep-the one with rachels inadvertant kiss.csv
# the one with rachels inadvertant kiss.csv
# friendsscraper/spiders/ep-the one where rachel finds out.csv
# the one where rachel finds out.csv
# friendsscraper/spiders/ep-the one with joeys big break.csv
# the one with joeys big break.csv
# friendsscraper/spiders/ep-the one with the lesbian wedding.csv
# the one with the lesbian wedding.csv
# friendsscraper/spiders/ep-the one where everyone finds out.csv
# the one where everyone finds out.csv
# friendsscraper/spiders/ep-the one with the chicken pox.csv
# the one with the chicken pox.csv
# friendsscraper/spiders/ep-the one with the proposal.csv
# the one with the proposal.csv
# friendsscraper/spiders/ep-the stuff youve never seen.csv
# the stuff youve never seen.csv
# friendsscraper/spiders/ep-the one with the halloween party.csv
# the one with the halloween party.csv
# friendsscraper/spiders/ep-the one with the nap partners.csv
# the one with the nap partners.csv
# friendsscraper/spiders/ep-the one with ross and monicas cousin.csv
# the one with ross and monicas cousin.csv
# friendsscraper/spiders/ep-the one where rachel smokes.csv
# the one where rachel smokes.csv
# friendsscraper/spiders/ep-the one with the routinue.csv
# the one with the routinue.csv
# friendsscraper/spiders/ep-the one in vegas.csv
# the one in vegas.csv
# friendsscraper/spiders/ep-the one with the embryos.csv
# the one with the embryos.csv
# friendsscraper/spiders/ep-the one with all the haste.csv
# the one with all the haste.csv
# friendsscraper/spiders/ep-the one with the boob job.csv
# the one with the boob job.csv
# friendsscraper/spiders/ep-the one with the ball.csv
# the one with the ball.csv
# friendsscraper/spiders/ep-the one after ross says rachel.csv
# the one after ross says rachel.csv
# friendsscraper/spiders/ep-the one where mr heckles dies.csv
# the one where mr heckles dies.csv
# friendsscraper/spiders/ep-the one where noones ready.csv
# the one where noones ready.csv
# friendsscraper/spiders/ep-the one with joeys award.csv
# the one with joeys award.csv
# friendsscraper/spiders/ep-the one with the sharks.csv
# the one with the sharks.csv
# friendsscraper/spiders/ep-the one where rachel is late.csv
# the one where rachel is late.csv
# friendsscraper/spiders/ep-the one with the blackout.csv
# the one with the blackout.csv
# friendsscraper/spiders/ep-the one with the free porn.csv
# the one with the free porn.csv
# friendsscraper/spiders/ep-the one with the ultimate fighting champion.csv
# the one with the ultimate fighting champion.csv
# friendsscraper/spiders/ep-the one where pauls the man.csv
# the one where pauls the man.csv
# friendsscraper/spiders/ep-the one with the cat.csv
# the one with the cat.csv
# friendsscraper/spiders/ep-the one after vegas.csv
# the one after vegas.csv
# friendsscraper/spiders/ep-the one with all the poker.csv
# the one with all the poker.csv
# friendsscraper/spiders/ep-the one with the home study.csv
# the one with the home study.csv
# friendsscraper/spiders/ep-the one with rachels dream.csv
# the one with rachels dream.csv
# friendsscraper/spiders/ep-the one with phoebes cookies.csv
# the one with phoebes cookies.csv
# friendsscraper/spiders/ep-the one with chandlers work laugh.csv
# the one with chandlers work laugh.csv
# friendsscraper/spiders/ep-the one with the ick factor.csv
# the one with the ick factor.csv
# friendsscraper/spiders/ep-the one where old yeller dies.csv
# the one where old yeller dies.csv
# friendsscraper/spiders/ep-the one with the girl who hits joey.csv
# the one with the girl who hits joey.csv
# friendsscraper/spiders/ep-the one with ross grant.csv
# the one with ross grant.csv
# friendsscraper/spiders/ep-the one with the dozen lasagnas.csv
# the one with the dozen lasagnas.csv
# friendsscraper/spiders/ep-the one with the cake.csv
# the one with the cake.csv
# friendsscraper/spiders/ep-the one with george stephanopoulos.csv
# the one with george stephanopoulos.csv
# friendsscraper/spiders/ep-the one with the race car bed.csv
# the one with the race car bed.csv
# friendsscraper/spiders/ep-the one where joey tells rachel.csv
# the one where joey tells rachel.csv
# friendsscraper/spiders/ep-the one with all the candy.csv
# the one with all the candy.csv
# friendsscraper/spiders/ep-the one where rachel has a baby.csv
# the one where rachel has a baby.csv
# friendsscraper/spiders/ep-the one with the football.csv
# the one with the football.csv
# friendsscraper/spiders/ep-the one with all the rugby.csv
# the one with all the rugby.csv
# friendsscraper/spiders/ep-the one where rachel and ross you know.csv
# the one where rachel and ross you know.csv
# friendsscraper/spiders/ep-the one the last night.csv
# the one the last night.csv
# friendsscraper/spiders/ep-the last one.csv
# the last one.csv
# friendsscraper/spiders/ep-the one where chandler doesnt like dogs.csv
# the one where chandler doesnt like dogs.csv
# friendsscraper/spiders/ep-the one without the ski trip.csv
# the one without the ski trip.csv
# friendsscraper/spiders/ep-the one with the lottery.csv
# the one with the lottery.csv
# friendsscraper/spiders/ep-the one where eddie moves in.csv
# the one where eddie moves in.csv
# friendsscraper/spiders/ep-the one with the joke.csv
# the one with the joke.csv
# friendsscraper/spiders/ep-the one with the cooking class.csv
# the one with the cooking class.csv
# friendsscraper/spiders/ep-the one after joey and rachel kiss.csv
# the one after joey and rachel kiss.csv

# %%
#ex = pd.read_csv('friendsscraper/spiders/processed_ep_the one with chandler in a box.csv', encoding='utf-8')
#ex.head(20)
ex_raw = pd.read_csv('friendsscraper/spiders/ep-the one with chandler in a box.csv')
ex_raw.head(20)
# Out:
#                        the one with chandler in a box
# 0                          Written by: Michael Borkow
# 1                                  \nTranscribed by:
# 2                                          Eric Aasen
# 3   [Scene: Chandler and Joeys, Joey is sitting at...
# 4                                               Joey:
# 5                            (answering phone) Hello.
# 6                                           Chandler:
# 7    (on phone) Hey, its me. I know you cant sta...
# 8                                             (Pause)
# 9                            (The phone rings again.)
# 10                                              Joey:
# 11                           (answering phone) Hello.
# 12                                          Chandler:
# 13   Look I never should have kissed your girlfrie...
# 14                                            (Pause)
# 15                       (The phone rings yet again.)
# 16                                              Joey:
# 17                   (answering phone) Stop callin!!
# 18                                             Voice:
# 19   (on phone) Hey! Hey! Hey! This is 92.3, WXRK,...

# %%
raw = pd.read_csv("friendsscraper/spiders/ep-the one where chandler crosses a line.csv")
raw.head(20)
# Out:
#                 the one where chandler crosses a line
# 0                              Written by: Adam Chase
# 1                                  \nTranscribed by:
# 2                                          Eric Aasen
# 3   [Scene: Monica and Rachel's, everyone except J...
# 4                                           Chandler:
# 5    (entering in a bathrobe) I just walked in the...
# 6                                               Ross:
# 7    Y'know if we ever go to war and youre captur...
# 8                                                 big
# 9                                           surprise.
# 10                                          Chandler:
# 11   It just keeps getting worse and worse! Y'know...
# 12                                            (Pause)
# 13                                            Phoebe:
# 14       Wow! Could everyone totally see up his robe?
# 15                                               All:
# 16                                   Yeah! Oh my God!
# 17                                    Opening Credits
# 18  [Scene: Central Perk, Joey is getting a phone ...
# 19                                             Casey:

# %%
raw_lines, ep_title = read_file("friendsscraper/spiders/ep-the one where chandler crosses a line.csv")
last_proc2 = process_script(raw_lines, ep_title)
# Out:
#                                                 lines
# 0               the one where chandler crosses a line
# 1                              Written by: Adam Chase
# 2                                  \nTranscribed by:
# 3                                          Eric Aasen
# 4   [Scene: Monica and Rachel's, everyone except J...
# 5                                           Chandler:
# 6    (entering in a bathrobe) I just walked in the...
# 7                                               Ross:
# 8    Y'know if we ever go to war and youre captur...
# 9                                                 big
# 10                                          surprise.
# 11                                          Chandler:
# 12   It just keeps getting worse and worse! Y'know...
# 13                                            (Pause)
# 14                                            Phoebe:
# 15       Wow! Could everyone totally see up his robe?
# 16                                               All:
# 17                                   Yeah! Oh my God!
# 18                                    Opening Credits
# 19  [Scene: Central Perk, Joey is getting a phone ...
# friendsscraper/spiders/ep-the one where chandler crosses a line.csv
# the one where chandler crosses a line.csv

# %%
last_proc2.head(50)
# Out:
#                        episode         scene  \
# 0   the one with all the poker  central perk
# 1   the one with all the poker  central perk
# 2   the one with all the poker  central perk
# 3   the one with all the poker  central perk
# 4   the one with all the poker  central perk
# 5   the one with all the poker  central perk
# 6   the one with all the poker  central perk
# 7   the one with all the poker  central perk
# 8   the one with all the poker  central perk
# 9   the one with all the poker  central perk
# 10  the one with all the poker  central perk
# 11  the one with all the poker  central perk
# 12  the one with all the poker  central perk
# 13  the one with all the poker  central perk
# 14  the one with all the poker  central perk
# 15  the one with all the poker  central perk
# 16  the one with all the poker  central perk
# 17  the one with all the poker  central perk
# 18  the one with all the poker  central perk
# 19  the one with all the poker  central perk
# 20  the one with all the poker  central perk
# 21  the one with all the poker  central perk
# 22  the one with all the poker  central perk
# 23  the one with all the poker  central perk
# 24  the one with all the poker  central perk
# 25  the one with all the poker  central perk
# 26  the one with all the poker  central perk
# 27  the one with all the poker  central perk
# 28  the one with all the poker  central perk
# 29  the one with all the poker  central perk
# 30  the one with all the poker  central perk
# 31  the one with all the poker  central perk
# 32  the one with all the poker  central perk
# 33  the one with all the poker  central perk
# 34  the one with all the poker  central perk
# 35  the one with all the poker  central perk
# 36  the one with all the poker  central perk
# 37  the one with all the poker  central perk
# 38  the one with all the poker  central perk
# 39  the one with all the poker  central perk
# 40  the one with all the poker  central perk
# 41  the one with all the poker  central perk
# 42  the one with all the poker  central perk
# 43  the one with all the poker  central perk
# 44  the one with all the poker  central perk
# 45  the one with all the poker  central perk
# 46  the one with all the poker  central perk
# 47  the one with all the poker  central perk
# 48  the one with all the poker  central perk
# 49  the one with all the poker  central perk
#
#                                             direction  \
# 0   ross and chandler are sitting at a table rache...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                            out loud
# 5                                  crumples up letter
# 6                                                None
# 7                                    crumpesup letter
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                     grabs the bill
# 12          camera cuts to chandler and ross at table
# 13                                               None
# 14                                               None
# 15                                               None
# 16                  beginsto stare lovingly at rachel
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                      sarcastically
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                         walks away
# 26  ross keeps staring at her head on table chandl...
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                       to the girls
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#                                            characters  \
# 0                                              monica
# 1                                   chandler and ross
# 2   hey hi ladies uh can i get you anything to mon...
# 3                                              monica
# 4                                           to monica
# 5                                             reading
# 6                                            out loud
# 7                                             reading
# 8                                              phoebe
# 9                                              rachel
# 10                                            reading
# 11                                             rachel
# 12                                               None
# 13                                           chandler
# 14                                               ross
# 15                                           chandler
# 16                                               ross
# 17                                           chandler
# 18                                               ross
# 19                                           chandler
# 20                                               ross
# 21                                           chandler
# 22  look i am totally totally over her ok i just r...
# 23                                             rachel
# 24                                               ross
# 25                                             rachel
# 26                                               None
# 27                                               joey
# 28                                           chandler
# 29                                             phoebe
# 30                                               ross
# 31                                               joey
# 32                                           chandler
# 33                                               joey
# 34                                               ross
# 35                                           chandler
# 36                                             rachel
# 37                                             phoebe
# 38                                               ross
# 39                                             phoebe
# 40                                           chandler
# 41                                               joey
# 42                                              girls
# 43                                             monica
# 44                                             rachel
# 45                                             monica
# 46                                               ross
# 47                                              girls
# 48                                             rachel
# 49                                               guys
#
#                                              dialogue
# 0                                            hey guys
# 1                                                 hey
# 2                              did you bring the mail
# 3                                   lots of responses
# 4                                              really
# 5   dear ms green thank you for your inquiry howev...
# 6                              we have apple cinnamon
# 7                  ok dear ms green yeah yeah yeah no
# 8                                                 wow
# 9                                                what
# 10                             your visa bill is huge
# 11                                       give me that
# 12                                               None
# 13  you know i cant believe you linda is so great ...
# 14                                        i dont know
# 15  is this still about her whole the flintstones ...
# 16  no its not just that its justi want someone w...
# 17                        little playthings with yarn
# 18                                               what
# 19                            could you want her more
# 20                                                who
# 21    dee the sarcastic sister from  whats happening
# 22                                              hiiii
# 23                                     hi how are you
# 24                                were fine were fine
# 25                                                 ok
# 26                                               None
# 27                                            shut up
# 28                  were notwere not saying anything
# 29                                               what
# 30                        uhhhh joey cried last night
# 31                                          thank you
# 32                      we were playing poker alright
# 33  there was chocolate on the three it looked lik...
# 34     oh guys you shouldve seen him read em and weep
# 35                                    and then he did
# 36  well now how come you guys have never played p...
# 37  yeah what is that like some kind of guy thing ...
# 38                       no women are welcome to play
# 39  oh ok so then what is it some kind of you know...
# 40  there just dont happen to be any women in our ...
# 41  yeah we just dont happen to know any women tha...
# 42                                      oh yeah right
# 43               oh please that is such a lame excuse
# 44                                             really
# 45                i mean thats a typical guy response
# 46         excuse me do any of  you  know how to play
# 47                                                 no
# 48                             but you could teach us
# 49                                                 no

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-281-f04be3cd3c56> in <module>
# ----> 1 np.isnan('a')
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
